# %%
import os

# %%
# %pwd
# Out:
# 'd:\\AI\\Kidney-Disease-Classification-MLflow-DVC\\research'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'd:\\AI\\Kidney-Disease-Classification-MLflow-DVC'

# %%
ML_FLOW_TRACKING_URI = 'https://dagshub.com/starmoorthy555/Kidney-Disease-Classification-MLflow-DVC.mlflow'

# %%
import dagshub
dagshub.init(repo_owner='starmoorthy555', repo_name='Kidney-Disease-Classification-MLflow-DVC', mlflow=True)

import mlflow
with mlflow.start_run():
  mlflow.log_param('parameter name', 'value')
  mlflow.log_metric('metric name', 1)
# Out:
# Accessing as starmoorthy555
# Initialized MLflow to track repo "starmoorthy555/Kidney-Disease-Classification-MLflow-DVC"
# Repository starmoorthy555/Kidney-Disease-Classification-MLflow-DVC initialized!

# %%
import tensorflow as tf

# %%
model  = tf.keras.models.load_model('artifacts/training/model.h5')

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class Evaluationconfiq:
    path_of_model : Path
    training_data : Path
    all_parms : dict
    mlflow_uri : str
    params_image_size : list
    params_batch_size : int
